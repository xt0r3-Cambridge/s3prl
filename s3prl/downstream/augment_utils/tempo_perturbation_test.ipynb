# %%
import torch
import torchaudio
from IPython.display import Audio, display

from s3prl.downstream.augment_utils.tempo_perturbation import TempoPerturbation
from s3prl.downstream.mdd.dataset import L2ArcticDataset
# Out:
# 2024-04-04 13:48:14.164293: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-04 13:48:14.196581: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-04 13:48:14.862970: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset = L2ArcticDataset(
    'train',
    '/home/xt0r3-user/cambridge/partii/dissertation/s3prl/data/l2arctic_release_v5.0',
    '/home/xt0r3-user/cambridge/partii/dissertation/s3prl/s3prl/s3prl/downstream/mdd/data/'
)
# Out:
# Skipping malformatted TextGrid file: /home/xt0r3-user/cambridge/partii/dissertation/s3prl/data/l2arctic_release_v5.0/YDCK/annotation/arctic_a0209.TextGrid

# %%
def play_audio(waveform, sample_rate):
  waveform = waveform.numpy()
  display(Audio(waveform, rate=sample_rate))

# %%
audio = torchaudio.functional.resample(dataset[0][0], orig_freq=44100, new_freq=16000)


play_audio(audio, 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
from scipy.interpolate import interp1d

def _validate_audio(audio):
    """validate the input audio and modify the order of channels.

    Parameters
    ----------

    audio : numpy.ndarray [shape=(channel, num_samples) or (num_samples)\
                           or (num_samples, channel)]
            the input audio sequence to validate.

    Returns
    -------

    audio : numpy.ndarray [shape=(channel, num_samples)]
            the validataed output audio sequence.
    """
    if audio.ndim == 1:
        audio = np.expand_dims(audio, 0)
    elif audio.ndim > 2:
        raise Exception("Please use the valid audio source. "
                        + "Number of dimension of input should be less than 3.")
    elif audio.shape[0] > audio.shape[1]:
        print('it seems that the 2nd axis of the input audio source '
             + 'is a channel. it is recommended that fix channel '
             + 'to the 1st axis.', stacklevel=3)
        audio = audio.T

    return audio


def _validate_scale_factor(audio, s):
    """Validate the scale factor s and
    convert the fixed scale factor to anchor points.

    Parameters
    ----------

    audio : numpy.ndarray [shape=(num_channels, num_samples) \
                           or (num_samples) or (num_samples, num_channels)]
            the input audio sequence.
    s : number > 0 [scalar] or numpy.ndarray [shape=(2, num_points) \
        or (num_points, 2)]
        the time stretching factor. Either a constant value (alpha)
        or an (2 x n) (or (n x 2)) array of anchor points
        which contains the sample points of the input signal in the first row
        and the sample points of the output signal in the second row.

    Returns
    -------

    anc_points : numpy.ndarray [shape=(2, num_points)]
                 anchor points which contains the sample points
                 of the input signal in the first row
                 and the sample points of the output signal in the second row.
    """
    if np.isscalar(s):
        anc_points = np.array([[0, np.shape(audio)[1] - 1],
                               [0, np.ceil(s * np.shape(audio)[1]) - 1]])
    elif s.ndim == 2:
        if s.shape[0] == 2:
            anc_points = s
        elif s.shape[1] == 2:
            print('it seems that the anchor points '
                 + 'has shape (num_points, 2). '
                 + 'it is recommended to '
                 + 'have shape (2, num_points).', stacklevel=3)
            anc_points = s.T
    else:
        raise Exception('Please use the valid anchor points. '
                        + '(scalar or pair of input/output sample points)')

    return anc_points

def wsola(x, s, win_type='hann',
          win_size=1024, syn_hop_size=512, tolerance=512):
    """Modify length of the audio sequence using WSOLA algorithm.

    Parameters
    ----------

    x : numpy.ndarray [shape=(channel, num_samples) or (num_samples)]
        the input audio sequence to modify.
    s : number > 0 [scalar] or numpy.ndarray [shape=(2, num_points)]
        the time stretching factor. Either a constant value (alpha)
        or an 2 x n array of anchor points which contains the sample points
        of the input signal in the first row
        and the sample points of the output signal in the second row.
    win_type : str
               type of the window function. hann and sin are available.
    win_size : int > 0 [scalar]
               size of the window function.
    syn_hop_size : int > 0 [scalar]
                   hop size of the synthesis window.
                   Usually half of the window size.
    tolerance : int >= 0 [scalar]
                number of samples the window positions
                in the input signal may be shifted
                to avoid phase discontinuities when overlap-adding them
                to form the output signal (given in samples).

    Returns
    -------

    y : numpy.ndarray [shape=(channel, num_samples) or (num_samples)]
        the modified output audio sequence.
    """
    # validate the input audio and scale factor.
    x = _validate_audio(x)
    anc_points = _validate_scale_factor(x, s)

    n_chan = x.shape[0]
    output_length = int(anc_points[-1, -1]) + 1

    display(f"{output_length}")



    win = torch.hann_window(win_size).numpy()

    sw_pos = np.arange(0, output_length + win_size // 2, syn_hop_size)
    ana_interpolated = interp1d(anc_points[1, :], anc_points[0, :],
                                fill_value='extrapolate')
    aw_pos = np.round(ana_interpolated(sw_pos)).astype(int)

    display(f"{sw_pos=}")
    display(f"{sw_pos.shape=}")
    display(f"{aw_pos=}")
    display(f"{aw_pos.shape=}")

    ana_hop = np.insert(aw_pos[1:] - aw_pos[0: -1], 0, 0)

    display(f"{ana_hop=}")

    y = np.zeros((n_chan, output_length))

    min_fac = np.min(syn_hop_size / ana_hop[1:])

    # padding the input audio sequence.
    left_pad = int(win_size // 2 + tolerance)
    right_pad = int(np.ceil(1 / min_fac) * win_size + tolerance)
    x_padded = np.pad(x, ((0, 0), (left_pad, right_pad)), 'constant')

    aw_pos = aw_pos + tolerance

    # Applying WSOLA to each channels
    for c, x_chan in enumerate(x_padded):
        y_chan = np.zeros(output_length + 2 * win_size)
        ow = np.zeros(output_length + 2 * win_size)

        delta = 0

        for i in range(len(aw_pos) - 1):
            x_adj = x_chan[aw_pos[i] + delta: aw_pos[i] + win_size + delta]
            y_chan[sw_pos[i]: sw_pos[i] + win_size] += x_adj * win
            ow[sw_pos[i]: sw_pos[i] + win_size] += win

            nat_prog = x_chan[aw_pos[i] + delta + syn_hop_size:
                              aw_pos[i] + delta + syn_hop_size + win_size]

            next_aw_range = np.arange(aw_pos[i+1] - tolerance,
                                      aw_pos[i+1] + win_size + tolerance)

            x_next = x_chan[next_aw_range]

            cross_corr = np.correlate(nat_prog, x_next)
            print(f"{cross_corr=}")
            print(f"{cross_corr.shape=}")

            max_index = np.argmax(cross_corr)

            delta = tolerance - max_index

        # Calculate last frame
        x_adj = x_chan[aw_pos[-1] + delta: aw_pos[-1] + win_size + delta]
        y_chan[sw_pos[-1]: sw_pos[-1] + win_size] += x_adj * win
        ow[sw_pos[-1]: sw_pos[-1] + win_size] += + win

        ow[ow < 1e-3] = 1

        y_chan = y_chan / ow
        y_chan = y_chan[win_size // 2:]
        y_chan = y_chan[: output_length]

        y[c, :] = y_chan

dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.05384151,  0.06843662,  0.08064932, ..., -0.19344679,
#        -0.22174709, -0.24846601], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 1.1459157 ,  1.0643384 ,  0.9623042 , ..., -0.62605226,
#        -0.5949081 , -0.53640634], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-2.0797186 , -2.1249552 , -2.16461   , ...,  0.44652647,
#         0.38847637,  0.31739593], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-2.1034184 , -2.090486  , -2.0605986 , ...,  0.35414165,
#         0.31491017,  0.26595446], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.7970716 , -0.76672006, -0.731959  , ...,  1.6332883 ,
#         1.6200821 ,  1.5994829 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.06621337, -0.06439115, -0.06041524, ...,  0.08836836,
#         0.09629793,  0.10321856], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.02501699, 0.02339097, 0.03173602, ..., 0.04139563, 0.03705432,
#        0.03154419], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.02912779, -0.02877321, -0.03157679, ...,  0.03837507,
#         0.03318171,  0.02845242], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.00885167, -0.00231688, -0.00559798, ..., -0.01207213,
#        -0.00653363, -0.01223811], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.01168354,  0.02719448,  0.01491556, ..., -0.04003528,
#        -0.0435179 , -0.04122794], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.0076583 ,  0.00184844,  0.00126723, ..., -0.00554299,
#         0.00803058,  0.000705  ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.01735897, 0.01559146, 0.01539626, ..., 0.03812075, 0.03900718,
#        0.03443883], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.01357956, -0.01436633, -0.01490655, ...,  0.00350683,
#        -0.0023046 , -0.00083285], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.00178372, -0.00134218, -0.00095123, ..., -0.00024989,
#        -0.00076713, -0.00171361], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.0052775 , -0.00579044, -0.00629135, ...,  0.00328449,
#         0.00317463,  0.00302953], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)
# cross_corr.shape=(1025,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
augmentation = TempoPerturbation(
    N=1024,
    sample_rate=16000,
    alpha_high=1.2,
    alpha_low=1.2,
    delta_max=512,
    prob=1.0,
)
play_audio(
    augmentation(
        [audio]
    )[0],
    sample_rate=16000,
)
# Out:
# new_len=94464
# cross_corr=tensor([-0.0046, -0.0051, -0.0056,  ..., -0.0059, -0.0059, -0.0058])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0134,  0.0140,  0.0149,  ..., -0.0072, -0.0073, -0.0074])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0732, -0.0737, -0.0747,  ...,  0.0298,  0.0305,  0.0307])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0927, -0.0877, -0.0823,  ..., -0.0014, -0.0006,  0.0004])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-2.7807e+00, -4.3720e+00, -5.7539e+00,  ..., -1.0145e-02,
#         -8.2858e-04,  7.1138e-03])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ -6.2454,  -8.4338, -10.5265,  ...,   0.1290,   0.1162,   0.1037])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-2.0561, -0.8229,  0.4008,  ...,  0.1509, -0.0137, -0.1794])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-16.4827, -18.6570, -20.2342,  ...,   4.5099,   5.0873,   5.6311])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 6.3136,  4.2439,  1.8336,  ...,  0.2962, -0.0219, -0.3555])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-4.6079, -4.3918, -3.9935,  ..., -3.3790, -2.1008, -0.8487])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 2.7834,  2.2561,  1.6822,  ..., -3.5721, -2.6845, -1.6209])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.2701, -0.3719, -0.4665,  ...,  0.0500,  0.0712,  0.0946])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0684,  0.0847,  0.1003,  ..., -0.1340, -0.0481,  0.0404])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0595, -0.0666, -0.0731,  ...,  0.2389,  0.2473,  0.2403])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.1700, -0.1742, -0.1769,  ..., -0.0682, -0.0700, -0.0702])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.2417, -0.2418, -0.2402,  ...,  0.0894,  0.1048,  0.1195])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0

# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0538,  0.0684,  0.0806,  ..., -0.1934, -0.2217, -0.2485])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 1.1459,  1.0643,  0.9623,  ..., -0.6261, -0.5949, -0.5364])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-2.0797, -2.1250, -2.1646,  ...,  0.4465,  0.3885,  0.3174])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-2.1034, -2.0905, -2.0606,  ...,  0.3541,  0.3149,  0.2660])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.7971, -0.7667, -0.7320,  ...,  1.6333,  1.6201,  1.5995])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0662, -0.0644, -0.0604,  ...,  0.0884,  0.0963,  0.1032])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.0250, 0.0234, 0.0317,  ..., 0.0414, 0.0371, 0.0315])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0291, -0.0288, -0.0316,  ...,  0.0384,  0.0332,  0.0285])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0089, -0.0023, -0.0056,  ..., -0.0121, -0.0065, -0.0122])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0117,  0.0272,  0.0149,  ..., -0.0400, -0.0435, -0.0412])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0077,  0.0018,  0.0013,  ..., -0.0055,  0.0080,  0.0007])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.0174, 0.0156, 0.0154,  ..., 0.0381, 0.0390, 0.0344])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0136, -0.0144, -0.0149,  ...,  0.0035, -0.0023, -0.0008])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0018, -0.0013, -0.0010,  ..., -0.0002, -0.0008, -0.0017])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0053, -0.0058, -0.0063,  ...,  0.0033,  0.0032,  0.0030])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0., 0., 0.,  ..., 0., 0., 0.])
# cross_corr.shape=torch.Size([1025])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = np.arange(1, 6)
v = np.arange(6, 8)
np.correlate(a, v)
# Out:
# array([20, 33, 46, 59])

# %%
x = torch.tensor(a, dtype=int)
w = torch.tensor(v, dtype=int)

augmentation.cross_correlate(w, x)
# Out:
# tensor([59, 46, 33, 20])

# %%
wsola(audio, 0.7) - augmentation(
    [audio]
)[0].numpy().max()
# Out:
# '55104'
# 'sw_pos=array([    0,   512,  1024,  1536,  2048,  2560,  3072,  3584,  4096,\n        4608,  5120,  5632,  6144,  6656,  7168,  7680,  8192,  8704,\n        9216,  9728, 10240, 10752, 11264, 11776, 12288, 12800, 13312,\n       13824, 14336, 14848, 15360, 15872, 16384, 16896, 17408, 17920,\n       18432, 18944, 19456, 19968, 20480, 20992, 21504, 22016, 22528,\n       23040, 23552, 24064, 24576, 25088, 25600, 26112, 26624, 27136,\n       27648, 28160, 28672, 29184, 29696, 30208, 30720, 31232, 31744,\n       32256, 32768, 33280, 33792, 34304, 34816, 35328, 35840, 36352,\n       36864, 37376, 37888, 38400, 38912, 39424, 39936, 40448, 40960,\n       41472, 41984, 42496, 43008, 43520, 44032, 44544, 45056, 45568,\n       46080, 46592, 47104, 47616, 48128, 48640, 49152, 49664, 50176,\n       50688, 51200, 51712, 52224, 52736, 53248, 53760, 54272, 54784,\n       55296])'
# 'sw_pos.shape=(109,)'
# 'aw_pos=array([    0,   731,  1463,  2194,  2926,  3657,  4389,  5120,  5851,\n        6583,  7314,  8046,  8777,  9509, 10240, 10971, 11703, 12434,\n       13166, 13897, 14629, 15360, 16092, 16823, 17554, 18286, 19017,\n       19749, 20480, 21212, 21943, 22674, 23406, 24137, 24869, 25600,\n       26332, 27063, 27794, 28526, 29257, 29989, 30720, 31452, 32183,\n       32914, 33646, 34377, 35109, 35840, 36572, 37303, 38034, 38766,\n       39497, 40229, 40960, 41692, 42423, 43155, 43886, 44617, 45349,\n       46080, 46812, 47543, 48275, 49006, 49737, 50469, 51200, 51932,\n       52663, 53395, 54126, 54857, 55589, 56320, 57052, 57783, 58515,\n       59246, 59977, 60709, 61440, 62172, 62903, 63635, 64366, 65097,\n       65829, 66560, 67292, 68023, 68755, 69486, 70218, 70949, 71680,\n       72412, 73143, 73875, 74606, 75338, 76069, 76800, 77532, 78263,\n       78995])'
# 'aw_pos.shape=(109,)'
# 'ana_hop=array([  0, 731, 732, 731, 732, 731, 732, 731, 731, 732, 731, 732, 731,\n       732, 731, 731, 732, 731, 732, 731, 732, 731, 732, 731, 731, 732,\n       731, 732, 731, 732, 731, 731, 732, 731, 732, 731, 732, 731, 731,\n       732, 731, 732, 731, 732, 731, 731, 732, 731, 732, 731, 732, 731,\n       731, 732, 731, 732, 731, 732, 731, 732, 731, 731, 732, 731, 732,\n       731, 732, 731, 731, 732, 731, 732, 731, 732, 731, 731, 732, 731,\n       732, 731, 732, 731, 731, 732, 731, 732, 731, 732, 731, 731, 732,\n       731, 732, 731, 732, 731, 732, 731, 731, 732, 731, 732, 731, 732,\n       731, 731, 732, 731, 732])'
# cross_corr=array([0.02619893, 0.02530554, 0.02475689, ..., 0.0081623 , 0.00789707,
#        0.00762186], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.03384878,  0.03525769,  0.03661398, ..., -0.00230931,
#        -0.00313931, -0.00378975], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.00739006, -0.0168961 , -0.02693434, ..., -0.00319701,
#        -0.00216035, -0.00180449], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([17.446142 , 16.282038 , 14.822403 , ...,  1.0346048,  0.3061338,
#        -0.4026743], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-5.106022  , -4.231931  , -3.2152295 , ..., -3.7088046 ,
#        -2.3615537 , -0.99671185], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([4.945966 , 5.242058 , 5.3545084, ..., 6.7825403, 6.2591376,
#        5.4482927], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 1.040566 ,  0.9338232,  0.810479 , ..., -8.744036 , -8.830133 ,
#        -8.682391 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.21079384, 0.17836565, 0.14329728, ..., 2.0860825 , 2.0991302 ,
#        2.067212  ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.08788933, 0.0797784 , 0.07124059, ..., 0.12737924, 0.13759556,
#        0.14563239], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.14089198,  0.14534664,  0.14739391, ..., -0.00753135,
#        -0.0259045 , -0.04207724], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.29507107, 0.2463743 , 0.19847184, ..., 0.22476776, 0.1502862 ,
#        0.07943854], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.64137733, -0.6853291 , -0.73057365, ..., -0.87278104,
#        -0.87662053, -0.87785506], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([8.367163 , 9.125721 , 9.65582  , ..., 1.1186284, 1.4741874,
#        1.7481344], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.01167054,  0.06815404,  0.1222261 , ..., -4.4423804 ,
#        -4.135968  , -3.71658   ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.09243271,  0.08143931,  0.06976581, ..., -0.47096136,
#        -0.5346781 , -0.5793644 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.0843817 , -0.07983872, -0.07449995, ..., -0.03272022,
#        -0.03471651, -0.03677678], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.802331  , -1.1645553 , -1.5012484 , ...,  0.22625433,
#         0.32908034,  0.41794288], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-2.218439 , -2.1604753, -2.0460997, ...,  1.2027197,  1.1574345,
#         1.0935366], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.5117667 , -0.34130782, -0.13005757, ..., -1.1157796 ,
#        -1.7460997 , -2.341927  ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 1.2160059,  1.1363852,  1.0267265, ..., 11.29986  , 11.377518 ,
#        11.238386 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-1.2169349, -1.2509422, -1.2834585, ...,  1.9326737,  1.5315428,
#         1.1868458], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.22639994, -0.20890686, -0.19007361, ..., -0.2321588 ,
#        -0.34475887, -0.46079487], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.029304  , -0.03363397, -0.03732004, ..., -0.08642443,
#        -0.08592021, -0.08693059], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-1.7538785 , -1.4352149 , -1.0829142 , ...,  0.25591522,
#         0.16806698,  0.09824567], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.14390548, -0.18443118, -0.23413783, ..., -2.1997452 ,
#        -2.2676601 , -2.31357   ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.32757577, 0.32066214, 0.31299293, ..., 0.71720314, 1.0577571 ,
#        1.4082246 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.24812502, -0.24450737, -0.24113941, ...,  0.04890105,
#         0.05097407,  0.05332831], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.04143742, -0.04546226, -0.04974325, ...,  0.14700252,
#         0.14334488,  0.13960767], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.07181223, -0.07057956, -0.06937687, ..., -0.12217   ,
#        -0.11667573, -0.11106152], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.08004903,  0.07899447,  0.0779388 , ..., -0.07391877,
#        -0.07514964, -0.07689762], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.06212498, 0.06310179, 0.0640584 , ..., 0.04288084, 0.04433516,
#        0.0458808 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.34260336, -0.34556943, -0.34847832, ..., -0.15765382,
#        -0.16140841, -0.16519457], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.18475133, 0.18583405, 0.18682086, ..., 0.29891786, 0.30186552,
#        0.30475357], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.07267421,  0.07197365,  0.07105087, ..., -0.18739673,
#        -0.18868454, -0.18995471], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.04685839, 0.05294916, 0.06050306, ..., 0.05969357, 0.05547662,
#        0.05192543], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([3.5069742 , 3.173388  , 2.7883513 , ..., 1.8674263 , 1.0974677 ,
#        0.27267006], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 2.8020463,  2.9855592,  3.1102443, ..., -2.2018166, -2.1094346,
#        -1.9325895], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([3.8924496 , 3.9146445 , 3.9066162 , ..., 0.45598045, 0.7106414 ,
#        0.9038985 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 3.213399 ,  2.7188718,  2.2268744, ..., -2.1916661, -1.9352801,
#        -1.5757322], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.92299366, 0.8206469 , 0.7429906 , ..., 6.2806406 , 6.7005663 ,
#        7.0416055 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.44236058, 0.46479183, 0.486585  , ..., 3.4977949 , 3.2784827 ,
#        3.0462518 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.05733703, 0.05674723, 0.05695045, ..., 0.7165215 , 0.64812696,
#        0.58261144], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.03905892,  0.03809061,  0.03709538, ..., -0.01453178,
#        -0.01405218, -0.01368447], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.02719904, -0.0269023 , -0.02610884, ...,  0.01787952,
#         0.01593585,  0.0139587 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.00053048,  0.00091335,  0.001552  , ..., -0.00493669,
#        -0.00570404, -0.00663756], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.05019142, -0.04917919, -0.04807231, ..., -0.03610817,
#        -0.0351807 , -0.0347086 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.0126233 , -0.01428311, -0.01597642, ...,  0.02663683,
#         0.02564672,  0.02481817], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.01168524,  0.01136288,  0.01103372, ..., -0.05980517,
#        -0.05718479, -0.05460057], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.00112014,  0.00138815,  0.00179528, ..., -0.02557919,
#        -0.02670676, -0.02784439], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.10745126,  0.09918974,  0.0906655 , ..., -0.00513586,
#        -0.01209596, -0.01877858], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.36678603,  0.42151475,  0.46284622, ..., -0.8639171 ,
#        -0.8707626 , -0.87715656], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 3.4002044,  3.7035847,  3.9309912, ...,  8.014017 ,  9.421914 ,
#        10.324764 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 3.0698044,  2.6921377,  2.2587516, ...,  0.787179 , -4.5034914,
#        -9.526388 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.16498041, -0.14061843, -0.13750209, ..., -6.108201  ,
#        -6.620056  , -6.8888817 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.19999781,  0.19821572,  0.19598846, ..., -0.48070967,
#        -0.47728318, -0.46921366], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 1.9777788e-02,  1.9768048e-02,  2.0137763e-02, ...,
#        -9.5092617e-03, -5.1707937e-03,  2.1126994e-05], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.00036386,  0.00506992,  0.00983233, ..., -0.05215577,
#        -0.05228763, -0.05144088], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 5.689024  ,  4.0490975 ,  2.61344   , ..., -0.1071972 ,
#        -0.11960512, -0.13465598], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-11.722415 ,  -9.948962 ,  -7.958794 , ...,   0.2134864,
#         -0.9598105,  -2.214106 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.73736393, 0.63804686, 0.5282248 , ..., 1.5411358 , 4.4337845 ,
#        6.970645  ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.20540094, 0.20842984, 0.22643578, ..., 6.229839  , 5.086786  ,
#        3.8993096 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 3.5925722 ,  3.4685688 ,  3.3074327 , ..., -0.23993157,
#        -0.21873058, -0.19986486], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-5.018941 , -4.8461804, -4.63653  , ..., -3.4655666, -3.4367943,
#        -3.3909554], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.9832313 ,  0.98616433,  0.98274136, ..., -0.34792465,
#        -0.66842234, -0.99419975], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-2.6831455, -2.9177651, -3.131575 , ...,  2.848671 ,  3.5740514,
#         4.2789764], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 5.445298 ,  5.307677 ,  5.097853 , ..., -2.3846118, -2.7373648,
#        -3.0254426], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.27125052, -0.16789055, -0.064153  , ...,  0.41710266,
#         0.44676977,  0.46524417], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.02706064,  0.01183195, -0.00235027, ..., -0.670603  ,
#        -0.7505039 , -0.8314193 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.00552527, 0.00597751, 0.00680966, ..., 0.03720404, 0.03906993,
#        0.04049186], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.02827793,  0.01605513,  0.00306606, ..., -0.01563662,
#        -0.01513933, -0.01464026], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.19968405, 0.2268629 , 0.2508961 , ..., 0.12061945, 0.12825425,
#        0.13994908], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.33008087, 0.33840036, 0.3429399 , ..., 0.5013162 , 0.36650965,
#        0.2354517 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.71576387, -0.67130315, -0.6262624 , ..., -1.1972923 ,
#        -1.1424391 , -1.0805435 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.73306096, 0.7607295 , 0.7919687 , ..., 0.50321746, 0.47655243,
#        0.45009872], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-1.9738269 , -1.1691658 , -0.35291523, ..., -2.3410501 ,
#        -2.350039  , -2.3153415 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.3438826 ,  0.35676092,  0.3635711 , ..., -3.8168292 ,
#        -3.5613365 , -3.1834686 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.08933517,  0.09171704,  0.09233199, ..., -0.70387113,
#        -0.63054097, -0.5558237 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.0307604 ,  0.03058699,  0.03020042, ..., -0.02127724,
#        -0.01567473, -0.00970407], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.09483013, 0.09801822, 0.10193762, ..., 0.0122679 , 0.01280188,
#        0.01177121], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 7.357546  ,  6.0936613 ,  4.758216  , ..., -0.17574137,
#         0.07488802,  0.28790876], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 2.2805614,  2.6562185,  2.980329 , ..., -2.5798616, -2.2517395,
#        -1.8669484], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-4.3411193, -4.0057287, -3.6112988, ..., -1.7170658, -2.2749245,
#        -2.8262417], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([2.7317123, 2.0809796, 1.4254289, ..., 6.15343  , 6.7732363,
#        7.344826 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-1.6821709, -1.3123398, -0.9443   , ..., -4.569771 , -4.4942303,
#        -4.379774 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.17111728, -0.33096674, -0.49932528, ...,  0.18643181,
#         0.06114659, -0.08954851], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-2.4301715, -1.8854606, -1.3057375, ..., -3.1985703, -2.5824916,
#        -1.9046409], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 1.1998143 ,  0.7865219 ,  0.3759324 , ...,  0.08950001,
#        -0.5228729 , -1.1054709 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.6111501 , 0.64706147, 0.6775687 , ..., 0.79028535, 0.9725689 ,
#        1.1398435 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.01504772, -0.01461199, -0.01352628, ..., -0.95509225,
#        -1.0031178 , -1.0441537 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.13605814,  0.13473845,  0.13339144, ..., -0.02825382,
#        -0.02394371, -0.0197701 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.00747543, -0.01845027, -0.03512457, ..., -0.06020108,
#        -0.05937764, -0.05926292], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.00995174, 0.01633899, 0.01677718, ..., 0.03293115, 0.05254509,
#        0.03910197], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.02078552,  0.00259025, -0.01879152, ...,  0.02435962,
#         0.01899667, -0.01181707], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.05239091, -0.11803951, -0.17635876, ..., -0.05963516,
#        -0.07739489, -0.08654109], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.11664431, 0.12242204, 0.12733883, ..., 0.18187127, 0.63359076,
#        1.0580816 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.03840406,  0.00293569, -0.03503662, ...,  1.544853  ,
#         0.90596384,  0.19502549], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.02897587,  0.02562279,  0.02287312, ..., -0.02952073,
#        -0.03525838, -0.03976459], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.10323514, -0.10135416, -0.09912047, ...,  0.03586489,
#         0.03177667,  0.01917781], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.15991247, 0.16838351, 0.1693686 , ..., 0.01889754, 0.01001866,
#        0.00239441], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-1.0620292 , -1.1052797 , -1.146518  , ..., -0.5885987 ,
#        -0.6315987 , -0.67915714], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.45466787,  0.48488614,  0.50425136, ..., -2.2226908 ,
#        -2.274074  , -2.2878644 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.14745635,  0.12762594,  0.1067724 , ..., -0.57136214,
#        -0.4309532 , -0.28486747], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.05337749, -0.05074444, -0.04795517, ...,  1.0234749 ,
#         0.94271076,  0.8578648 ], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.00331263,  0.01108541,  0.01161992, ..., -0.01679144,
#        -0.00922687, -0.01474611], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.03456797, -0.03568578, -0.03715488, ..., -0.01507574,
#        -0.02325565, -0.01536074], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([0.01008482, 0.01054256, 0.00885857, ..., 0.02937385, 0.04534359,
#        0.03347398], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([-0.00899244, -0.00903082, -0.00835457, ..., -0.0104386 ,
#        -0.01082237, -0.01130552], dtype=float32)
# cross_corr.shape=(1025,)
# cross_corr=array([ 0.        ,  0.        ,  0.        , ..., -0.02064363,
#        -0.02062591, -0.02060555], dtype=float32)
# cross_corr.shape=(1025,)
# new_len=39360
# cross_corr=tensor([-0.0015, -0.0023, -0.0029,  ...,  0.0667,  0.0671,  0.0674])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0457, -0.0495, -0.0527,  ...,  0.0177,  0.0177,  0.0178])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.8553, -1.6250, -2.4143,  ...,  2.4452,  2.1564,  1.7742])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-8.4208, -7.1760, -5.6929,  ...,  6.8926,  8.0861,  9.0075])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.3624,  0.5372,  0.6895,  ...,  1.0765, -0.8437, -2.8186])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.2076, -0.1128, -0.0107,  ..., -0.6600, -0.7618, -0.8487])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0209, -0.0168, -0.0130,  ...,  0.1949,  0.1988,  0.1993])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0395, -0.0292, -0.0146,  ...,  0.3867,  0.3830,  0.3776])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.4428,  0.2844,  0.9674,  ...,  0.6341,  0.9518,  1.2191])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.1300, -0.1328, -0.1361,  ...,  2.5914,  1.0144, -0.6359])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0337, -0.0357, -0.0382,  ..., -0.0578, -0.0242,  0.0083])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.1185, 0.1294, 0.1374,  ..., 0.0487, 0.0298, 0.0124])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-1.7579, -1.6174, -1.4647,  ...,  1.5916,  1.3186,  0.9918])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.8802,  1.1064,  1.3147,  ..., -2.2549, -1.4649, -0.6965])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-1.1747, -1.2104, -1.2416,  ...,  0.7029,  0.7670,  0.8422])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.1245, -0.1298, -0.1348,  ...,  1.1330,  1.1834,  1.2282])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.1702, -0.1756, -0.1767,  ...,  0.0377,  0.0386,  0.0388])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.3436, 0.4151, 0.4901,  ..., 1.5218, 2.0647, 2.5570])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.3961, -0.3911, -0.3856,  ..., -0.4408, -0.4485, -0.4509])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.1501, 0.1481, 0.1458,  ..., 0.3548, 0.3535, 0.3523])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.1276, 0.1270, 0.1265,  ..., 0.2149, 0.2133, 0.2119])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.0657, 0.0680, 0.0704,  ..., 0.1421, 0.1409, 0.1400])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.3134, 0.3161, 0.3187,  ..., 0.1992, 0.2035, 0.2077])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.0319, 0.0324, 0.0329,  ..., 0.2004, 0.2046, 0.2089])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.0369, 0.0218, 0.0065,  ..., 0.0166, 0.0172, 0.0181])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0682,  0.1869,  0.3217,  ..., -1.9938, -2.1173, -2.1627])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.8322, -0.6408, -0.4452,  ..., -1.0416, -1.2116, -1.3679])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.6972, -0.7594, -0.8246,  ...,  6.4510,  5.9476,  5.3652])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.8111, -0.8582, -0.9003,  ..., -1.6351, -1.4659, -1.3090])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.0059, 0.0085, 0.0118,  ..., 0.6853, 0.6295, 0.5787])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0401, -0.0392, -0.0384,  ...,  0.0157,  0.0144,  0.0131])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0208, -0.0210, -0.0213,  ...,  0.0014, -0.0004, -0.0013])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0160, -0.0164, -0.0166,  ...,  0.0021,  0.0017,  0.0014])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0981, -0.0975, -0.0969,  ..., -0.1782, -0.1792, -0.1803])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.1505,  0.1478,  0.1452,  ..., -0.1417, -0.1409, -0.1402])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([1.1244, 1.1177, 1.1072,  ..., 0.6780, 0.6603, 0.6407])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-2.2876, -2.5994, -2.8520,  ...,  9.1881,  9.7978, 10.0125])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.3935, -0.1707,  0.0866,  ...,  1.7137,  0.9962,  0.2103])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([0.0728, 0.0507, 0.0256,  ..., 5.3280, 5.2567, 5.0487])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0689, -0.0660, -0.0631,  ...,  0.0733,  0.0757,  0.0782])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0568,  0.0213, -0.0119,  ...,  0.0244,  0.0233,  0.0223])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-7.1654, -8.3052, -9.2679,  ...,  5.1612,  5.6278,  5.9570])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-1.7137, -1.7101, -1.6749,  ...,  6.7133,  4.5775,  2.0460])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.4363, -0.4012, -0.3978,  ..., -0.8750, -0.8185, -0.7707])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-1.7852, -1.5380, -1.2913,  ..., -2.6809, -2.5415, -2.3966])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-2.0960, -2.5668, -2.9810,  ..., -2.9664, -2.6127, -2.2509])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 2.3749,  1.8017,  1.2280,  ..., -3.4590, -3.2898, -3.0970])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.1437, -0.1893, -0.2371,  ..., -2.1928, -2.4916, -2.7375])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0368,  0.0378,  0.0390,  ..., -0.4168, -0.4611, -0.5017])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0506,  0.0495,  0.0477,  ..., -0.0123, -0.0121, -0.0119])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0887,  0.1295,  0.1677,  ..., -0.3855, -0.3525, -0.3186])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.3693,  0.3880,  0.4054,  ..., -0.2816, -0.3643, -0.4503])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.1154, -0.1670, -0.2136,  ...,  0.0638,  0.0276, -0.0089])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-1.0897, -0.9296, -0.7596,  ..., -3.4329, -4.2608, -4.9787])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0230,  0.0539,  0.0832,  ..., -0.6997, -0.6775, -0.6301])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0213,  0.0201,  0.0193,  ..., -0.0092, -0.0065, -0.0038])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-4.3592, -4.8579, -5.2540,  ..., -0.0085, -0.1540, -0.2994])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-3.7452, -3.9292, -4.0821,  ..., -4.2390, -3.6774, -3.0870])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.3907,  0.6221,  0.8329,  ..., -6.0463, -6.1517, -6.1920])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.3316,  0.5823,  0.8037,  ..., -3.8523, -3.5997, -3.3280])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.4630, -0.2826, -0.1198,  ..., -1.4410, -1.2132, -1.0123])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-1.5991, -1.4046, -1.2132,  ..., -1.6737, -1.4961, -1.3185])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0140,  0.0344,  0.0832,  ..., -2.3696, -2.1489, -1.9167])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0419, -0.0398, -0.0378,  ...,  0.1381,  0.1566,  0.1756])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0640, -0.0628, -0.0625,  ..., -0.0300, -0.0310, -0.0319])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0108,  0.0131,  0.0116,  ..., -0.0316, -0.0657, -0.0684])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0350, -0.0412, -0.0538,  ..., -0.0290, -0.0506,  0.0055])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.1120, -0.1008, -0.0886,  ..., -1.2544, -0.1932,  0.8958])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0812, -0.1333, -0.1832,  ...,  0.0692, -0.0240, -0.1165])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.1255, -0.1375, -0.1509,  ..., -0.0209, -0.0168, -0.0131])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0659, -0.0766, -0.1036,  ..., -0.4588, -0.4543, -0.4349])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.3609, -0.3946, -0.4348,  ...,  0.5762,  0.6629,  0.7195])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0113,  0.0146,  0.0193,  ..., -2.0016, -2.0013, -1.9828])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0286, -0.0244, -0.0191,  ...,  0.0501,  0.0551,  0.0588])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0141, -0.0137, -0.0136,  ...,  0.0163,  0.0064,  0.0138])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([-0.0039, -0.0041, -0.0036,  ..., -0.0250, -0.0255, -0.0131])
# cross_corr.shape=torch.Size([1025])
# cross_corr=tensor([ 0.0000,  0.0000,  0.0000,  ..., -0.0034, -0.0040, -0.0045])
# cross_corr.shape=torch.Size([1025])
# array([-0.41186122, -0.41181434, -0.41217723, ..., -0.43052027,
#        -0.42961884, -0.42992475])
